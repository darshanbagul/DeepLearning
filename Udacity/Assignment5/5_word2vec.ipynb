# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
      data = f.read(f.namelist()[0]).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'originated', 'a', 'as', 'of', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.872984
# Nearest to was: benchmarks, prohibit, fine, mozzarella, pioneer, gum, grenade, rubric,
# Nearest to used: budge, ou, vanunu, incident, naturalisation, vater, pontiff, admiring,
# Nearest to system: sprawling, pastiche, frescoes, bandai, cecil, fairy, ystok, cephalon,
# Nearest to of: pylons, reinstating, elections, mysteriously, structured, binet, mode, woodford,
# Nearest to that: striving, rugrats, ifs, diz, hoxha, louisa, forgave, verne,
# Nearest to b: biophysics, tobias, kara, like, slope, swallowed, soundboard, peso,
# Nearest to is: instincts, zander, euboea, cal, amazing, courtyards, foibles, zebrafish,
# Nearest to state: ionizing, unspeakable, eia, dissociative, certifications, lettering, krush, mie,
# Nearest to are: thrift, cia, founder, resembles, meeting, occidental, dent, xilinx,
# Nearest to five: scams, derivations, luis, idealist, findable, intrinsic, folks, ponte,
# Nearest to from: injunctions, ozarks, downloadable, knicks, nau, humidity, inspirations, daemon,
# Nearest to UNK: restorations, antiochus, election, expanding, oneself, hala, assuming, awkward,
# Nearest to th: squalor, queen, aquileia, weathering, reader, miko, isomorphism, notch,
# Nearest to had: labeling, fritz, separate, euston, ctor, mysticism, phelps, mcp,
# Nearest to time: plebeians, log, corticosteroids, abugida, esk, earthworks, doodle, aurangabad,
# Nearest to who: immature, weekdays, endometrium, meteorology, coll, elan, arc, amylase,
# Average loss at step 2000: 4.347738
# Average loss at step 4000: 3.867868
# Average loss at step 6000: 3.789003
# Average loss at step 8000: 3.688179
# Average loss at step 10000: 3.614023
# Nearest to was: is, had, has, were, be, by, are, midpoint,
# Nearest to used: aceh, referred, regarded, budge, byproducts, fiji, reacted, aung,
# Nearest to system: pastiche, redeem, relena, sprawling, endurance, frescoes, thermodynamic, fairy,
# Nearest to of: in, at, for, princesses, current, ner, legionnaire, kalinga,
# Nearest to that: which, this, trivalent, it, cheddar, shades, papier, hermas,
# Nearest to b: d, biophysics, normalizing, swallowed, quaternions, fusiliers, like, cliches,
# Nearest to is: was, are, jenkins, be, has, buckyballs, comnena, scholar,
# Nearest to state: brisance, telling, ionizing, unspeakable, penguins, kerensky, triple, certifications,
# Nearest to are: were, is, have, was, agglomeration, arose, riggs, skelton,
# Nearest to five: six, seven, eight, nine, three, four, zero, two,
# Nearest to from: in, husky, targ, with, scaling, by, on, gamemasters,
# Nearest to UNK: nationalities, resh, nottingham, opaque, fucked, she, destroyers, australian,
# Nearest to th: squalor, four, three, queen, aquileia, reader, seven, notch,
# Nearest to had: has, have, was, crankshaft, were, fritz, regeneration, kvac,
# Nearest to time: aurangabad, abugida, plebeians, esk, enrollments, behaviours, nijmegen, gish,
# Nearest to who: they, there, and, truncated, he, which, fini, that,
# Average loss at step 12000: 3.609114
# Average loss at step 14000: 3.569396
# Average loss at step 16000: 3.409077
# Average loss at step 18000: 3.458255
# Average loss at step 20000: 3.539062
# Nearest to was: is, were, had, has, became, be, are, does,
# Nearest to used: regarded, known, referred, reacted, fiji, byproducts, openly, budge,
# Nearest to system: endurance, relena, thermodynamic, redeem, pastiche, hotel, trains, fairy,
# Nearest to of: for, in, dhahran, arundel, universal, and, privatize, pedophilia,
# Nearest to that: which, but, papier, however, sensed, serious, eplf, targets,
# Nearest to b: d, biophysics, suborders, heroism, gita, apa, pavlov, affectionately,
# Nearest to is: was, has, are, be, but, jenkins, were, hogshead,
# Nearest to state: unspeakable, ionizing, brisance, defense, triple, aldehydes, idiosyncrasies, hawai,
# Nearest to are: were, is, have, was, skelton, aliyah, agesilaus, andante,
# Nearest to five: six, eight, seven, four, three, zero, two, nine,
# Nearest to from: into, in, and, targ, at, towards, with, through,
# Nearest to UNK: sunsets, xxii, jakobson, cliches, corners, sandy, exarch, supersede,
# Nearest to th: squalor, nd, five, rd, reader, notch, miles, one,
# Nearest to had: has, have, was, were, having, regeneration, kvac, who,
# Nearest to time: aurangabad, means, abugida, plebeians, day, faith, syria, alumnus,
# Nearest to who: he, which, they, then, there, also, often, never,
# Average loss at step 22000: 3.502073
# Average loss at step 24000: 3.490917
# Average loss at step 26000: 3.478856
# Average loss at step 28000: 3.478733
# Average loss at step 30000: 3.500766
# Nearest to was: is, has, had, were, became, been, be, does,
# Nearest to used: known, regarded, referred, able, found, byproducts, described, wmd,
# Nearest to system: systems, redeem, relena, pastiche, mindat, rope, au, olives,
# Nearest to of: in, privatize, pedophilia, idiosyncrasies, for, quartets, airframes, adele,
# Nearest to that: which, but, what, however, this, about, barefoot, hermas,
# Nearest to b: d, affectionately, biophysics, ehr, anton, horribly, heroism, hortense,
# Nearest to is: was, has, are, does, hegelians, be, became, but,
# Nearest to state: ionizing, unspeakable, blackwell, sly, nanna, parametric, defense, idiosyncrasies,
# Nearest to are: were, have, is, aliyah, include, be, these, andante,
# Nearest to five: four, eight, seven, six, three, zero, nine, two,
# Nearest to from: into, in, by, through, towards, targ, after, with,
# Nearest to UNK: nea, lawmaking, sanfl, pairings, sweetheart, jess, sherwood, herschel,
# Nearest to th: squalor, rd, nd, seven, six, bc, one, two,
# Nearest to had: has, have, was, were, having, labeling, when, crankshaft,
# Nearest to time: alumnus, day, means, faith, column, aurangabad, natured, manslaughter,
# Nearest to who: he, which, they, she, never, also, there, often,
# Average loss at step 32000: 3.504618
# Average loss at step 34000: 3.490390
# Average loss at step 36000: 3.458034
# Average loss at step 38000: 3.305934
# Average loss at step 40000: 3.426334
# Nearest to was: is, became, has, had, were, been, be, began,
# Nearest to used: known, referred, described, found, able, regarded, considered, reacted,
# Nearest to system: systems, relena, mindat, pastiche, fulbright, billing, thermodynamic, rope,
# Nearest to of: in, for, including, quackery, from, conti, original, carangi,
# Nearest to that: which, however, what, this, reassessment, trivalent, cheddar, deadweight,
# Nearest to b: d, c, anton, r, barbara, guelph, greenfacts, heroism,
# Nearest to is: was, are, has, be, contains, erlk, hogshead, ovum,
# Nearest to state: defense, nanna, council, government, unspeakable, idiosyncrasies, ionizing, sly,
# Nearest to are: were, have, is, these, aliyah, include, be, although,
# Nearest to five: seven, six, three, four, eight, two, nine, zero,
# Nearest to from: into, in, through, towards, of, mothman, after, wimbledon,
# Nearest to UNK: asu, convoked, rossby, judo, himself, elly, bob, j,
# Nearest to th: rd, squalor, bc, nd, six, seven, five, notch,
# Nearest to had: has, have, was, were, having, regeneration, kvac, crankshaft,
# Nearest to time: day, year, alumnus, abraxas, persists, means, winer, suffixed,
# Nearest to who: he, which, often, also, they, she, never, there,
# Average loss at step 42000: 3.435420
# Average loss at step 44000: 3.455592
# Average loss at step 46000: 3.450776
# Average loss at step 48000: 3.352580
# Average loss at step 50000: 3.384028
# Nearest to was: is, has, became, were, had, be, been, being,
# Nearest to used: known, referred, described, able, written, regarded, considered, produced,
# Nearest to system: systems, relena, fulbright, mindat, bundeswehr, billing, pastiche, rope,
# Nearest to of: and, in, including, bix, privatize, prevents, same, apostasy,
# Nearest to that: which, however, what, this, hermas, trivalent, lupin, widens,
# Nearest to b: d, c, r, pv, guelph, p, powell, w,
# Nearest to is: was, has, are, became, hogshead, becomes, be, does,
# Nearest to state: government, defense, council, nanna, revamp, idiosyncrasies, triple, detroit,
# Nearest to are: were, is, have, be, these, being, although, aliyah,
# Nearest to five: six, four, three, seven, eight, nine, zero, two,
# Nearest to from: into, through, in, after, husky, wimbledon, towards, targ,
# Nearest to UNK: stamford, levies, bovine, obverse, restorations, sandy, downloadable, straps,
# Nearest to th: rd, one, bc, squalor, six, eight, four, nd,
# Nearest to had: has, have, having, was, were, irenaeus, since, regeneration,
# Nearest to time: year, day, way, persists, statically, terms, means, breastfeeding,
# Nearest to who: which, he, never, they, she, often, there, truncated,
# Average loss at step 52000: 3.435146
# Average loss at step 54000: 3.427883
# Average loss at step 56000: 3.439179
# Average loss at step 58000: 3.397570
# Average loss at step 60000: 3.387062
# Nearest to was: is, became, had, were, has, be, been, does,
# Nearest to used: known, described, referred, written, considered, wmd, produced, regarded,
# Nearest to system: systems, rope, mindat, relena, base, billing, celera, pastiche,
# Nearest to of: for, in, bix, same, ingeborg, bromwich, including, mallow,
# Nearest to that: which, what, however, this, trivalent, venturi, trowa, because,
# Nearest to b: d, c, guelph, m, p, tilde, r, nonnegative,
# Nearest to is: was, are, became, seems, has, be, does, describes,
# Nearest to state: government, defense, council, nanna, whistleblower, revamp, idiosyncrasies, remaining,
# Nearest to are: were, is, have, include, skelton, these, be, aliyah,
# Nearest to five: six, eight, three, four, seven, nine, zero, two,
# Nearest to from: into, through, chambered, armistice, in, mothman, durham, flicker,
# Nearest to UNK: industrially, mathrm, restorations, crc, gwh, stamford, nep, submissions,
# Nearest to th: five, bc, six, rd, eight, squalor, four, nd,
# Nearest to had: has, have, was, were, having, russification, regeneration, been,
# Nearest to time: day, statically, transfusion, persists, year, way, means, offense,
# Nearest to who: which, he, never, she, now, eventually, still, often,
# Average loss at step 62000: 3.241603
# Average loss at step 64000: 3.256132
# Average loss at step 66000: 3.398874
# Average loss at step 68000: 3.395621
# Average loss at step 70000: 3.356225
# Nearest to was: is, has, had, were, became, been, be, although,
# Nearest to used: referred, known, described, written, responsible, considered, regarded, produced,
# Nearest to system: systems, rope, savvy, mindat, relena, billing, pastiche, celera,
# Nearest to of: including, original, include, privatize, hosokawa, prairies, flensburg, in,
# Nearest to that: which, what, however, but, often, this, trivalent, venturi,
# Nearest to b: d, r, frac, n, c, guelph, p, f,
# Nearest to is: was, has, be, are, seems, became, federer, makes,
# Nearest to state: government, nanna, defense, council, private, unspeakable, whistleblower, stilgar,
# Nearest to are: were, have, is, be, these, include, those, including,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to from: into, through, in, mothman, towards, between, amboise, inside,
# Nearest to UNK: mathrm, inscribed, wells, stamford, sweetheart, beryllium, discontinuing, rossby,
# Nearest to th: bc, rd, squalor, nd, seven, miguel, one, four,
# Nearest to had: has, have, was, were, having, regeneration, been, russification,
# Nearest to time: day, statically, way, hag, cases, kind, persists, offense,
# Nearest to who: never, often, he, she, actually, eventually, truncated, leo,
# Average loss at step 72000: 3.376006
# Average loss at step 74000: 3.346343
# Average loss at step 76000: 3.312213
# Average loss at step 78000: 3.347794
# Average loss at step 80000: 3.378216
# Nearest to was: is, became, were, had, has, be, been, wrote,
# Nearest to used: referred, described, known, written, given, available, responsible, wmd,
# Nearest to system: systems, rope, mindat, relena, pastiche, savvy, boric, fulbright,
# Nearest to of: in, including, entire, original, conti, current, homestead, graz,
# Nearest to that: which, however, what, trivalent, boast, barefoot, lupin, hermas,
# Nearest to b: d, c, r, guelph, p, afdb, frac, n,
# Nearest to is: was, has, hogshead, are, became, seems, be, becomes,
# Nearest to state: government, nanna, council, states, sixth, unspeakable, detroit, stilgar,
# Nearest to are: were, is, include, have, these, be, those, including,
# Nearest to five: six, four, eight, seven, three, nine, zero, two,
# Nearest to from: into, through, in, by, husky, idiomatic, including, during,
# Nearest to UNK: blotting, viii, williams, man, shorelines, decorations, xiii, buchanan,
# Nearest to th: bc, squalor, rd, nd, four, miguel, five, six,
# Nearest to had: have, has, was, were, having, russification, been, regeneration,
# Nearest to time: statically, hag, year, day, cases, hostility, orbit, offense,
# Nearest to who: often, he, never, she, actually, which, usually, there,
# Average loss at step 82000: 3.408932
# Average loss at step 84000: 3.410590
# Average loss at step 86000: 3.389914
# Average loss at step 88000: 3.348665
# Average loss at step 90000: 3.359976
# Nearest to was: is, had, became, were, has, be, been, deciphering,
# Nearest to used: referred, known, described, designed, given, seen, considered, written,
# Nearest to system: systems, mindat, celera, pastiche, rope, savvy, barons, relena,
# Nearest to of: including, in, for, physical, dhahran, biggest, entire, original,
# Nearest to that: which, however, what, but, arrogant, trivalent, boast, imi,
# Nearest to b: d, r, c, k, frac, p, afdb, g,
# Nearest to is: was, has, are, be, becomes, does, seems, describes,
# Nearest to state: government, unspeakable, council, nanna, defense, states, auditor, tyranny,
# Nearest to are: were, is, include, have, these, be, those, overvalued,
# Nearest to five: eight, four, seven, six, three, nine, zero, two,
# Nearest to from: into, through, during, towards, husky, mannheim, with, kibaki,
# Nearest to UNK: flax, narbonne, cretan, mc, kinship, wastewater, whatsoever, xxii,
# Nearest to th: six, seven, bc, rd, miguel, squalor, nd, five,
# Nearest to had: has, have, was, were, having, russification, regeneration, since,
# Nearest to time: day, year, hag, way, statically, cases, bottle, obstacles,
# Nearest to who: he, often, actually, never, but, adrian, truncated, which,
# Average loss at step 92000: 3.400062
# Average loss at step 94000: 3.252949
# Average loss at step 96000: 3.358983
# Average loss at step 98000: 3.243904
# Average loss at step 100000: 3.356026
# Nearest to was: is, became, has, had, were, been, being, deciphering,
# Nearest to used: referred, described, written, given, known, designed, considered, produced,
# Nearest to system: systems, relena, model, compromised, process, straus, celera, au,
# Nearest to of: including, and, in, pitfalls, privatize, original, entire, licit,
# Nearest to that: which, what, however, who, but, nevertheless, when, certainly,
# Nearest to b: d, apa, brac, sinn, biophysics, raped, c, greenfacts,
# Nearest to is: was, has, became, seems, becomes, hogshead, are, refers,
# Nearest to state: nanna, council, unspeakable, auditor, states, hydroxyl, detroit, lepidus,
# Nearest to are: were, have, include, these, be, those, is, although,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to from: into, in, through, amboise, towards, during, strangled, at,
# Nearest to UNK: reed, villain, welling, sinai, mathrm, thruster, cretan, olney,
# Nearest to th: rd, bc, nd, one, squalor, miguel, bce, second,
# Nearest to had: has, have, having, was, russification, were, regeneration, irenaeus,
# Nearest to time: statically, year, day, round, kind, way, mention, days,
# Nearest to who: he, actually, never, she, often, usually, that, truncated,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# For the continuous bag of words, the train inputs are slightly different from the skip-gram:

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.193241
# Nearest to its: engel, bury, undertones, elevate, sari, hypertalk, carnap, oliphant,
# Nearest to be: dangers, adults, presides, neurologic, axon, virginia, forbidding, taiko,
# Nearest to it: abul, amazons, ou, anime, grown, oversaw, outsiders, duality,
# Nearest to also: splinter, mohs, roleplaying, contras, rebounding, pubmed, hiawatha, tapu,
# Nearest to up: jakarta, lansdowne, maroger, resulted, matrilineal, um, scenic, splashdown,
# Nearest to i: engravers, hungry, laughlin, galway, preterite, hypotheses, afer, specification,
# Nearest to who: citrus, reichsf, proceeding, bolshevist, hayao, quirk, muppet, doppelbock,
# Nearest to new: granites, evacuate, artwork, coagulation, aman, het, rearranging, calvin,
# Nearest to other: alkaloids, escorting, remarkably, obsession, wiesbaden, wedlock, drowned, portability,
# Nearest to th: shifts, uninteresting, belvedere, bandanese, apex, gottwald, researchers, nighttime,
# Nearest to so: important, sdp, pratyeka, emphasis, adamic, endpoint, ssris, habitually,
# Nearest to six: experimentation, destroy, actinide, radiant, modifiers, pcr, hanukkah, piled,
# Nearest to which: maguire, commercially, chee, cumin, messiah, mersenne, issuing, audi,
# Nearest to while: radiating, folktales, hanoi, napo, clauses, powerhouse, bju, stamps,
# Nearest to is: governess, klement, suevi, listeners, rinnan, gemayel, francis, freefall,
# Nearest to a: mss, crimea, incidence, meitner, truthful, beep, prevention, dunst,
# Average loss at step 2000: 14.320580
# Average loss at step 4000: 4.428939
# Average loss at step 6000: 4.117652
# Average loss at step 8000: 3.760863
# Average loss at step 10000: 3.561622
# Nearest to its: their, his, the, matchup, lexicology, this, catchment, kashubians,
# Nearest to be: antimatter, was, agnostic, abram, physician, israeli, chipset, even,
# Nearest to it: he, there, she, this, udma, forced, crystallographic, eratosthenes,
# Nearest to also: which, crackers, interoperable, not, below, nosed, backups, directories,
# Nearest to up: jakarta, down, alzheimer, divulge, collective, lansdowne, andrey, eritrea,
# Nearest to i: relaxing, herat, ii, aces, culbert, ant, plurals, title,
# Nearest to who: blossomed, that, he, tomorrowland, she, which, by, eccentricity,
# Nearest to new: graphics, capitalist, brokered, het, assembled, suez, effector, gels,
# Nearest to other: many, some, several, these, epi, croat, more, those,
# Nearest to th: glowing, semicolon, belvedere, terrible, jer, toolkits, reluctance, flickering,
# Nearest to so: worshipped, twice, before, even, antimatter, sick, faith, be,
# Nearest to six: eight, five, seven, four, zero, nine, three, fracturing,
# Nearest to which: that, and, also, marginal, novella, who, improvising, this,
# Nearest to while: before, agnostic, abram, during, antimatter, atheists, chipset, attendance,
# Nearest to is: are, has, tsarist, ranged, did, pleas, wrote, invest,
# Nearest to a: an, the, this, scorpion, kew, nast, busway, breasts,
# Average loss at step 12000: 3.591484
# Average loss at step 14000: 3.529776
# Average loss at step 16000: 3.750708
# Average loss at step 18000: 3.510505
# Average loss at step 20000: 3.406321
# Nearest to its: their, his, the, her, chases, catchment, lewin, this,
# Nearest to be: refer, have, continue, harlan, occur, caen, dangers, provide,
# Nearest to it: he, she, this, zoff, essequibo, hyperplasia, tm, hello,
# Nearest to also: often, below, still, salamander, which, now, sidelined, stoicism,
# Nearest to up: off, down, out, him, display, corp, accepted, yer,
# Nearest to i: ii, title, aces, wobble, cyrus, herat, hopkinson, gerd,
# Nearest to who: she, blossomed, he, posting, bodybuilding, darkly, bangkok, carnivores,
# Nearest to new: graphics, het, architecture, escaped, unusual, rolling, dispositions, converged,
# Nearest to other: different, possessing, various, lifecycle, more, erm, orgy, those,
# Nearest to th: st, franciscan, analyzer, seventeenth, hire, twentieth, phoenician, abbeville,
# Nearest to so: meister, believe, curule, bled, aerobatics, zapata, daley, incorporation,
# Nearest to six: eight, three, seven, four, five, two, aerosmith, toolkits,
# Nearest to which: bcd, hemp, abram, antimatter, r, online, that, cane,
# Nearest to while: when, but, although, and, after, where, of, before,
# Nearest to is: was, are, were, became, has, tsarist, means, contains,
# Nearest to a: the, another, any, this, vedanta, exterminating, pathologic, worldcom,
# Average loss at step 22000: 3.463767
# Average loss at step 24000: 3.394728
# Average loss at step 26000: 3.343967
# Average loss at step 28000: 3.474551
# Average loss at step 30000: 3.301659
# Nearest to its: their, his, her, the, oriente, isbns, our, boac,
# Nearest to be: refer, being, provide, bring, occur, make, lead, elitism,
# Nearest to it: she, he, this, there, cartagena, which, hyperplasia, still,
# Nearest to also: still, below, often, insurgents, disambiguation, crackers, currently, not,
# Nearest to up: off, down, out, lavishly, jakarta, together, parabolic, attempts,
# Nearest to i: ii, g, zoning, antithesis, physicians, herat, ai, reductase,
# Nearest to who: blossomed, posting, whom, masamune, jaws, darkly, he, bobble,
# Nearest to new: phane, het, garb, turkmenistan, workings, skunk, rectangle, dole,
# Nearest to other: different, these, crucified, lifecycle, several, all, some, those,
# Nearest to th: st, nd, seventeenth, twentieth, phoenician, nineteenth, adrenaline, hurd,
# Nearest to so: too, hemphill, wb, sometimes, norm, supine, zapata, sportswriters,
# Nearest to six: eight, seven, nine, four, five, zero, three, two,
# Nearest to which: what, this, that, where, disfigured, it, frontispiece, flynn,
# Nearest to while: although, and, when, towards, but, after, lillian, tatra,
# Nearest to is: was, are, became, has, were, remains, methodius, means,
# Nearest to a: another, the, any, an, pathologic, no, this, exterminating,
# Average loss at step 32000: 3.289953
# Average loss at step 34000: 3.278699
# Average loss at step 36000: 3.251671
# Average loss at step 38000: 3.220578
# Average loss at step 40000: 3.220413
# Nearest to its: their, his, the, her, your, ils, our, medallist,
# Nearest to be: refer, being, occur, lead, have, produce, remain, clicking,
# Nearest to it: he, she, this, there, cartagena, tennant, saxo, unclear,
# Nearest to also: below, still, disambiguation, now, salamander, drowning, which, often,
# Nearest to up: off, down, out, jakarta, him, pluck, ariane, alzheimer,
# Nearest to i: g, ii, nash, iv, giroux, herat, modify, ethnically,
# Nearest to who: blossomed, whom, she, living, bangkok, couples, which, masamune,
# Nearest to new: unplugged, workings, cristina, convinces, phane, unusual, burghers, het,
# Nearest to other: various, others, different, rather, ostia, these, reopened, lifecycle,
# Nearest to th: st, nd, twentieth, nineteenth, seventeenth, rd, third, hire,
# Nearest to so: too, curule, machinations, hemphill, ripe, argue, believe, sally,
# Nearest to six: four, eight, seven, five, three, zero, nine, asquith,
# Nearest to which: that, this, where, usually, carmichael, these, however, also,
# Nearest to while: cryonics, nanotechnology, including, antimatter, abram, chipset, agnostic, bcpl,
# Nearest to is: was, are, has, remains, were, became, includes, becomes,
# Nearest to a: any, another, every, the, each, this, an, ifc,
# Average loss at step 42000: 3.252523
# Average loss at step 44000: 3.173718
# Average loss at step 46000: 3.176162
# Average loss at step 48000: 3.116247
# Average loss at step 50000: 3.095015
# Nearest to its: their, his, our, her, the, fretting, your, nils,
# Nearest to be: being, refer, lead, occur, produce, become, bring, remain,
# Nearest to it: he, she, this, there, hyperplasia, essequibo, they, what,
# Nearest to also: below, still, now, usually, currently, disambiguation, often, sometimes,
# Nearest to up: off, out, down, him, walid, jakarta, them, nicaraguan,
# Nearest to i: g, ii, we, iii, anyway, ethnically, exceeding, lingering,
# Nearest to who: she, blossomed, which, aitken, madox, already, lawmakers, whom,
# Nearest to new: unplugged, burghers, different, phane, confessor, amf, earlier, modern,
# Nearest to other: various, these, different, others, persons, ostia, cramps, lifecycle,
# Nearest to th: nd, rd, st, twentieth, nineteenth, third, second, vol,
# Nearest to so: cryonics, era, hemp, et, chiapas, antimatter, houses, dinosaurs,
# Nearest to six: five, four, seven, eight, three, nine, zero, h,
# Nearest to which: that, what, this, where, actually, usually, who, also,
# Nearest to while: although, when, however, and, cleef, rinzai, unlike, though,
# Nearest to is: was, are, remains, contains, became, were, means, gives,
# Nearest to a: any, another, the, bamar, every, luo, ifc, fiduciary,
# Average loss at step 52000: 3.150997
# Average loss at step 54000: 3.147079
# Average loss at step 56000: 2.975634
# Average loss at step 58000: 3.046547
# Average loss at step 60000: 3.075214
# Nearest to its: their, his, her, our, the, vampires, livecd, s,
# Nearest to be: lead, being, refer, remain, produce, occur, become, provide,
# Nearest to it: he, she, this, what, pirated, jimmie, there, cartagena,
# Nearest to also: generally, cryonics, condoms, now, below, collar, still, currently,
# Nearest to up: off, out, down, parabolic, reputedly, songs, zel, nobita,
# Nearest to i: ii, g, k, sucre, cruz, l, tamil, riff,
# Nearest to who: blossomed, which, whom, posting, aqua, he, she, already,
# Nearest to new: unplugged, phane, wide, different, confessor, spark, large, small,
# Nearest to other: various, persons, others, several, these, lifecycle, different, both,
# Nearest to th: nd, nineteenth, rd, st, seventeenth, twentieth, third, cg,
# Nearest to so: too, believe, naively, ripe, ruud, note, argue, objector,
# Nearest to six: five, four, eight, seven, nine, three, zero, ss,
# Nearest to which: that, where, this, what, who, actually, usually, whose,
# Nearest to while: although, and, when, however, if, but, though, among,
# Nearest to is: was, has, are, includes, became, exists, remains, gives,
# Nearest to a: another, any, the, every, no, ifc, wallet, casts,
# Average loss at step 62000: 3.036542
# Average loss at step 64000: 2.943585
# Average loss at step 66000: 2.961692
# Average loss at step 68000: 2.984972
# Average loss at step 70000: 3.026876
# Nearest to its: their, his, the, our, her, livecd, s, lewin,
# Nearest to be: refer, being, remain, lead, become, mean, occur, produce,
# Nearest to it: he, she, this, cartagena, sunk, pirated, breasts, omnibus,
# Nearest to also: below, still, disambiguation, currently, now, which, already, never,
# Nearest to up: off, down, out, parabolic, holstein, ellipsoid, together, nicaraguan,
# Nearest to i: g, you, ii, we, intensities, terminates, little, tamil,
# Nearest to who: blossomed, which, brahmic, he, that, young, lawmakers, whose,
# Nearest to new: unplugged, skunk, overwrite, different, copylefted, celebrates, revitalization, large,
# Nearest to other: various, others, lifecycle, cramps, multiple, jornal, older, different,
# Nearest to th: nd, st, nineteenth, seventeenth, rd, twentieth, third, cvn,
# Nearest to so: too, bleed, argue, believe, ll, hemphill, depressing, mondays,
# Nearest to six: seven, five, three, eight, four, zero, richards, two,
# Nearest to which: that, where, this, what, also, who, actually, although,
# Nearest to while: but, although, however, though, and, when, snowmobiles, unlike,
# Nearest to is: was, are, makes, remains, includes, has, exists, becomes,
# Nearest to a: another, the, any, every, cimmeria, vedanta, this, an,
# Average loss at step 72000: 2.969216
# Average loss at step 74000: 2.882976
# Average loss at step 76000: 3.006550
# Average loss at step 78000: 3.016987
# Average loss at step 80000: 2.865551
# Nearest to its: their, his, her, the, scarcely, your, our, theropods,
# Nearest to be: refer, remain, being, lead, produce, provide, occur, become,
# Nearest to it: he, she, this, omnibus, probably, cartagena, there, today,
# Nearest to also: still, disambiguation, now, below, currently, never, sometimes, already,
# Nearest to up: down, off, back, out, nicaraguan, jurisprudence, together, pluck,
# Nearest to i: ii, g, you, culbert, we, iii, spada, immunity,
# Nearest to who: whom, which, blossomed, he, biggs, born, young, already,
# Nearest to new: unplugged, specific, skunk, wide, old, different, small, hardwired,
# Nearest to other: lifecycle, various, others, fewer, individual, different, these, smaller,
# Nearest to th: nd, st, nineteenth, seventeenth, rd, twentieth, nine, third,
# Nearest to so: sometimes, too, believe, what, now, enol, objectivity, reaching,
# Nearest to six: four, eight, seven, five, three, zero, nine, two,
# Nearest to which: that, where, this, what, who, these, contractor, whom,
# Nearest to while: though, although, when, where, and, whereas, however, because,
# Nearest to is: was, makes, remains, are, gives, contains, becomes, includes,
# Nearest to a: another, any, the, enough, reorganize, piqad, pathologic, each,
# Average loss at step 82000: 2.946955
# Average loss at step 84000: 2.907185
# Average loss at step 86000: 2.935193
# Average loss at step 88000: 2.957348
# Average loss at step 90000: 2.848384
# Nearest to its: their, the, his, phrygian, presley, banjo, methadone, pinned,
# Nearest to be: remain, refer, lead, occur, being, produce, represent, serve,
# Nearest to it: he, she, this, there, they, itself, cartagena, omnibus,
# Nearest to also: still, disambiguation, currently, below, sometimes, never, which, already,
# Nearest to up: off, down, back, out, technicality, forth, jakarta, away,
# Nearest to i: g, ii, iv, homebrew, song, iii, indie, micromachining,
# Nearest to who: whom, which, blossomed, lawmakers, homemade, biggs, burrows, flutie,
# Nearest to new: mutant, geocache, homologous, sleeps, impart, celebrates, unplugged, typical,
# Nearest to other: various, different, others, cramps, fewer, septuagint, multiple, older,
# Nearest to th: nineteenth, nd, st, seventeenth, rd, twentieth, sixteenth, fifth,
# Nearest to so: too, sometimes, zapata, believe, fact, gees, naively, argue,
# Nearest to six: four, seven, five, eight, three, nine, zero, two,
# Nearest to which: that, where, what, this, actually, typically, whom, also,
# Nearest to while: although, though, and, when, however, or, among, plus,
# Nearest to is: was, are, remains, becomes, makes, exists, has, became,
# Nearest to a: another, any, the, every, this, unwarranted, piqad, knit,
# Average loss at step 92000: 2.909661
# Average loss at step 94000: 2.902500
# Average loss at step 96000: 2.718771
# Average loss at step 98000: 2.484517
# Average loss at step 100000: 2.732396
# Nearest to its: their, his, her, our, the, your, isbns, whose,
# Nearest to be: remain, occur, refer, being, lead, mean, serve, have,
# Nearest to it: he, she, there, probably, evident, omnibus, cartagena, this,
# Nearest to also: now, disambiguation, currently, still, below, often, actually, already,
# Nearest to up: off, out, down, together, technicality, back, parabolic, terse,
# Nearest to i: you, we, ii, iv, iii, little, sequencer, bfi,
# Nearest to who: whom, which, blossomed, he, burrows, she, lawmakers, sibilant,
# Nearest to new: unplugged, brokered, raw, roommate, mutant, geocache, balanced, angie,
# Nearest to other: others, fewer, various, lifecycle, different, individual, older, cramps,
# Nearest to th: nd, nineteenth, rd, st, seventeenth, twentieth, fifth, thirteenth,
# Nearest to so: argue, too, hemphill, sometimes, swallowed, believe, swear, substratum,
# Nearest to six: seven, five, eight, four, zero, three, two, weighs,
# Nearest to which: that, typically, where, this, when, also, whom, what,
# Nearest to while: though, but, and, when, although, vashem, meanwhile, or,
# Nearest to is: was, remains, represents, are, holds, contains, becomes, has,
# Nearest to a: another, the, eastbourne, any, every, no, enough, rugova,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
animal_sim = {
    'cat': final_embeddings[2600],
    'kitty' : final_embeddings[17386],
    'kitten' : final_embeddings[35405],
    'dog' : final_embeddings[1902],
    'puppy' : final_embeddings[3302],
}

# %%
reverse_dictionary.values().index('puppy')
# Out:
# 33052

# %%
def word_similarity(v1,v2):
    n = np.dot(v1,v2.T)
    d = np.sqrt(np.sum(v1**2))*np.sqrt(np.sum(v2**2))
    return float(n)/d

# %%
for v1 in animal_sim.keys():
    for v2 in animal_sim.keys():
        print("Similarity between " + str(v1) + " & " + str(v2) + " is: " + str(word_similarity(animal_sim[v1],animal_sim[v2])))
# Out:
# Similarity between kitten & kitten is: 1.00000011921
# Similarity between kitten & kitty is: 0.142787077593
# Similarity between kitten & dog is: -0.0556081570685
# Similarity between kitten & puppy is: -0.0177142492192
# Similarity between kitten & cat is: -0.148942882075
# Similarity between kitty & kitten is: 0.142787077593
# Similarity between kitty & kitty is: 1.0
# Similarity between kitty & dog is: -0.137958579538
# Similarity between kitty & puppy is: -0.0246719836602
# Similarity between kitty & cat is: -0.32796939278
# Similarity between dog & kitten is: -0.0556081570685
# Similarity between dog & kitty is: -0.137958579538
# Similarity between dog & dog is: 1.0
# Similarity between dog & puppy is: 0.165950377697
# Similarity between dog & cat is: 0.298273551876
# Similarity between puppy & kitten is: -0.0177142492192
# Similarity between puppy & kitty is: -0.0246719836602
# Similarity between puppy & dog is: 0.165950377697
# Similarity between puppy & puppy is: 0.999999880791
# Similarity between puppy & cat is: -0.0414782862093
# Similarity between cat & kitten is: -0.148942882075
# Similarity between cat & kitty is: -0.32796939278
# Similarity between cat & dog is: 0.298273551876
# Similarity between cat & puppy is: -0.0414782862093
# Similarity between cat & cat is: 1.00000011921
